# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('../data/data.csv')

# %%
df.head(10)
# Out:
#    id  player_fifa_api_id  player_api_id        date  overall_rating  \
# 0   1              218353         505942  2016-02-18            67.0
# 1   2              218353         505942  2015-11-19            67.0
# 2   3              218353         505942  2015-09-21            62.0
# 3   4              218353         505942  2015-03-20            61.0
# 4   5              218353         505942  2007-02-22            61.0
# 5   6              189615         155782  2016-04-21            74.0
# 6   7              189615         155782  2016-04-07            74.0
# 7   8              189615         155782  2016-01-07            73.0
# 8   9              189615         155782  2015-12-24            73.0
# 9  10              189615         155782  2015-12-17            73.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# ...

# %%
df['overall_rating'].isnull().sum()
# Out:
# 836

# %%
features_with_id=[i for i in df.columns if 'id' in i and i!='sliding_tackle']
features_with_id
# Out:
# ['id', 'player_fifa_api_id', 'player_api_id']

# %% [markdown]
# ###### Removing "features_with_id" as they are not required

# %%
df.head(5)
# Out:
#    id  player_fifa_api_id  player_api_id        date  overall_rating  \
# 0   1              218353         505942  2016-02-18            67.0
# 1   2              218353         505942  2015-11-19            67.0
# 2   3              218353         505942  2015-09-21            62.0
# 3   4              218353         505942  2015-03-20            61.0
# 4   5              218353         505942  2007-02-22            61.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
# 2       66.0          right              medium              medium      49.0
# 3       65.0          right              medium              medium      48.0
# 4       65.0          right              medium              medium      48.0
#
#    ...  vision  penalties  marking  standing_tackle  sliding_tackle  \
# ...

# %%
for feature in features_with_id:
    df = df.drop(feature,axis=1)

# %%
df.head()
# Out:
#          date  overall_rating  potential preferred_foot attacking_work_rate  \
# 0  2016-02-18            67.0       71.0          right              medium
# 1  2015-11-19            67.0       71.0          right              medium
# 2  2015-09-21            62.0       66.0          right              medium
# 3  2015-03-20            61.0       65.0          right              medium
# 4  2007-02-22            61.0       65.0          right              medium
#
#   defensive_work_rate  crossing  finishing  heading_accuracy  short_passing  \
# 0              medium      49.0       44.0              71.0           61.0
# 1              medium      49.0       44.0              71.0           61.0
# 2              medium      49.0       44.0              71.0           61.0
# 3              medium      48.0       43.0              70.0           60.0
# 4              medium      48.0       43.0              70.0           60.0
#
# ...

# %% [markdown]
# ###### Removing "date" as it is also not required for model training and prediction

# %%
df.drop(columns='date',inplace=True)

# %%
df.head()
# Out:
#    overall_rating  potential preferred_foot attacking_work_rate  \
# 0            67.0       71.0          right              medium
# 1            67.0       71.0          right              medium
# 2            62.0       66.0          right              medium
# 3            61.0       65.0          right              medium
# 4            61.0       65.0          right              medium
#
#   defensive_work_rate  crossing  finishing  heading_accuracy  short_passing  \
# 0              medium      49.0       44.0              71.0           61.0
# 1              medium      49.0       44.0              71.0           61.0
# 2              medium      49.0       44.0              71.0           61.0
# 3              medium      48.0       43.0              70.0           60.0
# 4              medium      48.0       43.0              70.0           60.0
#
#    volleys  ...  vision  penalties  marking  standing_tackle  sliding_tackle  \
# ...

# %% [markdown]
# ##### Working on Numerical Features for Missing Values!!

# %%
df.isnull().sum()
# Out:
# overall_rating          836
# potential               836
# preferred_foot          836
# attacking_work_rate    3230
# defensive_work_rate     836
# crossing                836
# finishing               836
# heading_accuracy        836
# short_passing           836
# volleys                2713
# dribbling               836
# curve                  2713
# free_kick_accuracy      836
# long_passing            836
# ball_control            836
# acceleration            836
# sprint_speed            836
# agility                2713
# reactions               836
# balance                2713
# shot_power              836
# jumping                2713
# stamina                 836
# strength                836
# long_shots              836
# aggression              836
# interceptions           836
# positioning             836
# vision                 2713
# penalties               836
# marking                 836
# standing_tackle         836
# sliding_tackle         2713
# ...

# %% [markdown]
# As we can see there are lot of missing values...Let's sort it out

# %%
len(df['overall_rating'])

print("As we can see 183978 >>>836, hence no need to use Imputers anymore")
# Out:
# As we can see 183978 >>>836, hence no need to use Imputers anymore

# %%
df=df.dropna(subset=['overall_rating'])

# %%
df.isnull().sum()
# Out:
# overall_rating            0
# potential                 0
# preferred_foot            0
# attacking_work_rate    2394
# defensive_work_rate       0
# crossing                  0
# finishing                 0
# heading_accuracy          0
# short_passing             0
# volleys                1877
# dribbling                 0
# curve                  1877
# free_kick_accuracy        0
# long_passing              0
# ball_control              0
# acceleration              0
# sprint_speed              0
# agility                1877
# reactions                 0
# balance                1877
# shot_power                0
# jumping                1877
# stamina                   0
# strength                  0
# long_shots                0
# aggression                0
# interceptions             0
# positioning               0
# vision                 1877
# penalties                 0
# marking                   0
# standing_tackle           0
# sliding_tackle         1877
# ...

# %%
df = df.dropna(subset=['attacking_work_rate','volleys'])

# %%
df.isna().sum()
# Out:
# overall_rating         0
# potential              0
# preferred_foot         0
# attacking_work_rate    0
# defensive_work_rate    0
# crossing               0
# finishing              0
# heading_accuracy       0
# short_passing          0
# volleys                0
# dribbling              0
# curve                  0
# free_kick_accuracy     0
# long_passing           0
# ball_control           0
# acceleration           0
# sprint_speed           0
# agility                0
# reactions              0
# balance                0
# shot_power             0
# jumping                0
# stamina                0
# strength               0
# long_shots             0
# aggression             0
# interceptions          0
# positioning            0
# vision                 0
# penalties              0
# marking                0
# standing_tackle        0
# sliding_tackle         0
# gk_diving              0
# gk_handling            0
# gk_kicking             0
# gk_positioning         0
# ...

# %% [markdown]
# ##### Handling categorical variables

# %%
categorical_features=[features for features in df.columns if df[features].dtype=='O']
categorical_features
# Out:
# ['preferred_foot', 'attacking_work_rate', 'defensive_work_rate']

# %% [markdown]
# ##### Applying "ONE HOT ENCODING" as it will work better in our case
#
# >>>Here's the link to know more about Encoding Techniques: https://towardsdatascience.com/6-ways-to-encode-features-for-machine-learning-algorithms-21593f6238b0

# %%
df = pd.get_dummies(df, columns = categorical_features, drop_first=True)
df
# Out:
#         overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0                 67.0       71.0      49.0       44.0              71.0
# 1                 67.0       71.0      49.0       44.0              71.0
# 2                 62.0       66.0      49.0       44.0              71.0
# 3                 61.0       65.0      48.0       43.0              70.0
# 4                 61.0       65.0      48.0       43.0              70.0
# ...                ...        ...       ...        ...               ...
# 183973            83.0       85.0      84.0       77.0              59.0
# 183974            78.0       80.0      74.0       76.0              53.0
# 183975            77.0       80.0      74.0       71.0              53.0
# 183976            78.0       81.0      74.0       64.0              57.0
# 183977            80.0       81.0      74.0       68.0              57.0
#
#         short_passing  volleys  dribbling  curve  free_kick_accuracy  ...  \
# ...

# %%
df.columns[df.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
df.to_csv("../data/data.csv",index=None)

# %%
numerical_features=[features for features in df.columns if df[features].dtype!='O' and features not in features_with_id]
numerical_features

plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in numerical_features:
    if plotnumber<=35 :
        ax = plt.subplot(9,4,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=20)
        #plt.ylabel('Salary',fontsize=20)
    plotnumber+=1
plt.tight_layout()
# Out:
# d:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# d:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# d:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...
